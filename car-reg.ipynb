# %%
import pandas as pd
df = pd.read_csv('car.csv')
df
from imblearn.over_sampling import SMOTEN
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# from ydata_profiling import ProfileReport
# profile = ProfileReport(df,explorative=True)
# profile.to_file('car.html')

# %%
df.columns
df.info()
df['horsepower'].replace("?", None, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
y = df['mpg']
x = df.drop(['mpg', 'car name'], axis=1)
# df["horsepower"] = df['horsepower'].astype('float64')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# from lazypredict.Supervised import LazyRegressor
# lazy_predict = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
# models, predictions = lazy_predict.fit(x_train,x_test,y_train,y_test)
# print(models)
# print(predictions)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler

# %%
num_transform = Pipeline(steps=[
    ('imputer', SimpleImputer( strategy='median')),
    ('scale',StandardScaler())
])
# nominal_transform = Pipeline(steps=[
#     ('imputer', SimpleImputer(strategy='most_frequent')),
#      ('nominal', OneHotEncoder())
# ])
# ordinal_transform = Pipeline(steps =[
#     ('imputer', SimpleImputer(strategy=  'most_frequent')),
#     ('encoder', OrdinalEncoder())
# ])
x_train = num_transform.fit_transform(x_train)
x_test = num_transform.transform(x_test)

# %%
from lazypredict.Supervised import LazyRegressor
lazy_predict = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models, predictions = lazy_predict.fit(x_train,x_test,y_train,y_test)
models
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 28.75it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000035 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 318, number of used features: 7
# [LightGBM] [Info] Start training from score 23.608176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

reg = Pipeline(steps=[
    ('preprocessor',num_transform),
    ('model', RandomForestRegressor())
])
reg.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                                  ('scale', StandardScaler())])),
#                 ('model', RandomForestRegressor())])

# %%
y_predict = reg.predict(x_test)
from sklearn.metrics import r2_score, mean_squared_error
print(f'R2: {r2_score(y_test, y_predict)}')
# Out:
# R2: 0.9116057008605857

# %%
from sklearn.model_selection import GridSearchCV
params = {
    "preprocessor__imputer__strategy" : ['mean', 'median'],
    "model__n_estimators": [100,200,300],
    "model__criterion" : ["poisson", "absolute_error", "squared_error"],
}
grid_search = GridSearchCV(estimator = reg, param_grid= params, cv=5,scoring='r2',verbose=1)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         Pipeline(steps=[('imputer',
#                                                          SimpleImputer(strategy='median')),
#                                                         ('scale',
#                                                          StandardScaler())])),
#                                        ('model', RandomForestRegressor())]),
#              param_grid={'model__criterion': ['poisson', 'absolute_error',
#                                               'squared_error'],
#                          'model__n_estimators': [100, 200, 300],
#                          'preprocessor__imputer__strategy': ['mean', 'median']},
#              scoring='r2', verbose=1)

# %%
y_predict = grid_search.predict(x_test)

# %%
print(grid_search.best_estimator_)
print(grid_search.best_params_)
# model = grid_search.best_estimator_
# y_predict2 = grid_search.predict(x_test)
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                  ('scale', StandardScaler())])),
#                 ('model', RandomForestRegressor(criterion='absolute_error'))])
# {'model__criterion': 'absolute_error', 'model__n_estimators': 100, 'preprocessor__imputer__strategy': 'mean'}

# %%
print(f'R2: {r2_score(y_test,y_predict)}')
# Out:
# R2: 0.9146002818207593

# %%
print(f'R2: {r2_score(y_test,y_predict2)}')
# Out:
# R2: 0.8959729326702496
